# %%
# Out:
# Initally Image Looks Like
#
# [[[174  73 140]
#   [140 172  41]
#   [187 198 158]]
#
#  [[178 183 177]
#   [190 133  78]
#   [166  19 102]]
#
#  [[ 35  89 146]
#   [196  66 109]
#   [113 148  44]]]
#
#
# After Swapping Image Looks Like
#
# [[[ 44  73 140]
#   [140 172  41]
#   [187 198 158]]
#
#  [[178 183 177]
#   [190 133  78]
#   [166  19 102]]
#
#  [[ 35  89 146]
#   [196  66 109]
#   [113 148 174]]]
